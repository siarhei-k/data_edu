# %%
import pandas as pd

train_path = '/home/sk/Downloads/insurance_claim/train.csv'
test_path = '/home/sk/Downloads/insurance_claim/test.csv'

train_data = pd.read_csv(train_path) 
test_data = pd.read_csv(test_path)

# %%
# All categorical columns
object_cols = [col for col in train_data.columns if train_data[col].dtype == "object"]

from sklearn.preprocessing  import OrdinalEncoder

ordinal_encoder = OrdinalEncoder()

train_data[object_cols] = ordinal_encoder.fit_transform(train_data[object_cols])

test_data[object_cols] = ordinal_encoder.transform(test_data[object_cols])

# %%
train_data
# Out:
#             id  cat0  cat1  cat2  cat3  cat4  cat5  cat6  cat7  cat8  ...  \
# 0            1   1.0   1.0   1.0   2.0   1.0   1.0   0.0   4.0   2.0  ...
# 1            2   1.0   1.0   0.0   0.0   1.0   3.0   0.0   5.0   0.0  ...
# 2            3   0.0   0.0   0.0   2.0   1.0   3.0   0.0   3.0   0.0  ...
# 3            4   1.0   1.0   0.0   2.0   1.0   3.0   0.0   4.0   2.0  ...
# 4            6   0.0   0.0   0.0   2.0   1.0   3.0   0.0   4.0   0.0  ...
# ...        ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 299995  499993   1.0   1.0   0.0   0.0   1.0   3.0   0.0   4.0   0.0  ...
# 299996  499996   0.0   1.0   0.0   2.0   1.0   1.0   0.0   4.0   4.0  ...
# 299997  499997   1.0   1.0   0.0   2.0   1.0   2.0   0.0   4.0   6.0  ...
# 299998  499998   0.0   1.0   0.0   2.0   1.0   1.0   0.0   4.0   4.0  ...
# 299999  499999   0.0   0.0   0.0   2.0   0.0   3.0   0.0   4.0   0.0  ...
#
#            cont5     cont6     cont7     cont8     cont9    cont10    cont11  \
# 0       0.400361  0.160266  0.310921  0.389470  0.267559  0.237281  0.377873
# 1       0.533087  0.558922  0.516294  0.594928  0.341439  0.906013  0.921701
# 2       0.650609  0.375348  0.902567  0.555205  0.843531  0.748809  0.620126
# 3       0.668980  0.239061  0.732948  0.679618  0.574844  0.346010  0.714610
# 4       0.686964  0.420667  0.648182  0.684501  0.956692  1.000773  0.776742
# ...          ...       ...       ...       ...       ...       ...       ...
# 299995  0.769792  0.450538  0.934360  1.005077  0.853726  0.422541  1.063463
# 299996  0.528056  0.508502  0.358247  0.257825  0.433525  0.301015  0.268447
# 299997  0.688747  0.372425  0.364936  0.383224  0.551825  0.661007  0.629606
# 299998  0.344404  0.424243  0.382028  0.468819  0.351036  0.288768  0.611169
# 299999  0.565347  0.328669  0.789165  0.960406  0.776019  0.734707  0.484392
#
#           cont12    cont13    target
# 0       0.322401  0.869850  8.113634
# 1       0.261975  0.465083  8.481233
# 2       0.541474  0.763846  8.364351
# 3       0.540150  0.280682  8.049253
# 4       0.625849  0.250823  7.972260
# ...          ...       ...       ...
# 299995  0.697685  0.506404  7.945605
# 299996  0.577055  0.823611  7.326118
# 299997  0.714139  0.245732  8.706755
# 299998  0.380254  0.332030  7.229569
# 299999  0.639754  0.689317  8.631146
#
# [300000 rows x 26 columns]

# %%
from sklearn import preprocessing

lab_enc = preprocessing.LabelEncoder()

encoded_y = lab_enc.fit_transform(y)

# %%
encoded_y
# Out:
# array([139782, 192118, 171561, ..., 222759,  31378, 216781])

# %%
features = train_data.columns.tolist()[1:-1]

# %%
features
# Out:
# ['cat0',
#  'cat1',
#  'cat2',
#  'cat3',
#  'cat4',
#  'cat5',
#  'cat6',
#  'cat7',
#  'cat8',
#  'cat9',
#  'cont0',
#  'cont1',
#  'cont2',
#  'cont3',
#  'cont4',
#  'cont5',
#  'cont6',
#  'cont7',
#  'cont8',
#  'cont9',
#  'cont10',
#  'cont11',
#  'cont12',
#  'cont13']

# %%
y = train_data.target
X = train_data[features]

# %%
X
# Out:
#         cat0  cat1  cat2  cat3  cat4  cat5  cat6  cat7  cat8  cat9  ...  \
# 0        1.0   1.0   1.0   2.0   1.0   1.0   0.0   4.0   2.0  13.0  ...
# 1        1.0   1.0   0.0   0.0   1.0   3.0   0.0   5.0   0.0  14.0  ...
# 2        0.0   0.0   0.0   2.0   1.0   3.0   0.0   3.0   0.0   5.0  ...
# 3        1.0   1.0   0.0   2.0   1.0   3.0   0.0   4.0   2.0  10.0  ...
# 4        0.0   0.0   0.0   2.0   1.0   3.0   0.0   4.0   0.0  13.0  ...
# ...      ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 299995   1.0   1.0   0.0   0.0   1.0   3.0   0.0   4.0   0.0   8.0  ...
# 299996   0.0   1.0   0.0   2.0   1.0   1.0   0.0   4.0   4.0   5.0  ...
# 299997   1.0   1.0   0.0   2.0   1.0   2.0   0.0   4.0   6.0   5.0  ...
# 299998   0.0   1.0   0.0   2.0   1.0   1.0   0.0   4.0   4.0   8.0  ...
# 299999   0.0   0.0   0.0   2.0   0.0   3.0   0.0   4.0   0.0  14.0  ...
#
#            cont4     cont5     cont6     cont7     cont8     cont9    cont10  \
# 0       0.610706  0.400361  0.160266  0.310921  0.389470  0.267559  0.237281
# 1       0.276853  0.533087  0.558922  0.516294  0.594928  0.341439  0.906013
# 2       0.285074  0.650609  0.375348  0.902567  0.555205  0.843531  0.748809
# 3       0.284667  0.668980  0.239061  0.732948  0.679618  0.574844  0.346010
# 4       0.287595  0.686964  0.420667  0.648182  0.684501  0.956692  1.000773
# ...          ...       ...       ...       ...       ...       ...       ...
# 299995  0.307883  0.769792  0.450538  0.934360  1.005077  0.853726  0.422541
# 299996  0.736713  0.528056  0.508502  0.358247  0.257825  0.433525  0.301015
# 299997  0.277074  0.688747  0.372425  0.364936  0.383224  0.551825  0.661007
# 299998  0.805963  0.344404  0.424243  0.382028  0.468819  0.351036  0.288768
# 299999  0.276785  0.565347  0.328669  0.789165  0.960406  0.776019  0.734707
#
#           cont11    cont12    cont13
# 0       0.377873  0.322401  0.869850
# 1       0.921701  0.261975  0.465083
# 2       0.620126  0.541474  0.763846
# 3       0.714610  0.540150  0.280682
# 4       0.776742  0.625849  0.250823
# ...          ...       ...       ...
# 299995  1.063463  0.697685  0.506404
# 299996  0.268447  0.577055  0.823611
# 299997  0.629606  0.714139  0.245732
# 299998  0.611169  0.380254  0.332030
# 299999  0.484392  0.639754  0.689317
#
# [300000 rows x 24 columns]

# %%
from sklearn.model_selection import train_test_split

train_X, val_X, train_y, val_y = train_test_split(X, encoded_y, train_size=0.8, test_size=0.2)

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn import datasets
# Import train_test_split function
from sklearn.model_selection import train_test_split
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics

# %%
# Create adaboost classifer object
abc = AdaBoostClassifier(n_estimators=50,
                         learning_rate=1)
# Train Adaboost Classifer
model = abc.fit(train_X, train_y)

#Predict the response for test dataset
valid_pred = model.predict(val_X)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-12-6b3f32645d5b> in <module>
#       3                          learning_rate=1)
#       4 # Train Adaboost Classifer
# ----> 5 model = abc.fit(train_X, train_y)
#       6
#       7 #Predict the response for test dataset
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_weight_boosting.py in fit(self, X, y, sample_weight)
#     441
#     442         # Fit
# --> 443         return super().fit(X, y, sample_weight)
#     444
#     445     def _validate_estimator(self):
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_weight_boosting.py in fit(self, X, y, sample_weight)
#     128         for iboost in range(self.n_estimators):
#     129             # Boosting step
# --> 130             sample_weight, estimator_weight, estimator_error = self._boost(
#     131                 iboost,
#     132                 X, y,
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_weight_boosting.py in _boost(self, iboost, X, y, sample_weight, random_state)
#     501         """
#     502         if self.algorithm == 'SAMME.R':
# --> 503             return self._boost_real(iboost, X, y, sample_weight, random_state)
#     504
#     505         else:  # elif self.algorithm == "SAMME":
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_weight_boosting.py in _boost_real(self, iboost, X, y, sample_weight, random_state)
#     513         estimator.fit(X, y, sample_weight=sample_weight)
#     514
# --> 515         y_predict_proba = estimator.predict_proba(X)
#     516
#     517         if iboost == 0:
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py in predict_proba(self, X, check_input)
#     929         check_is_fitted(self)
#     930         X = self._validate_X_predict(X, check_input)
# --> 931         proba = self.tree_.predict(X)
#     932
#     933         if self.n_outputs_ == 1:
#
# sklearn/tree/_tree.pyx in sklearn.tree._tree.Tree.predict()
#
# sklearn/tree/_tree.pyx in sklearn.tree._tree.Tree.predict()
#
# MemoryError: Unable to allocate 429. GiB for an array with shape (240000, 1, 239752) and data type float64

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(val_y, valid_pred)
mae
