# %% [markdown]
# Task 1

# %%
from math import sin, exp
import numpy as np
from scipy.optimize import minimize

# %%
x = np.arange(1, 30, 0.01)
fx = np.sin(x/5.)*np.exp(x/10.) + 5*np.exp(-x/2.)

# %%
def fun(x):
    return np.sin(x/5.)*np.exp(x/10.) + 5*np.exp(-x/2.)

# %%
x0 = 2
res = minimize(fun, x0, method='BFGS')
print(res)
# Out:
#       fun: 1.7452682903449388
#  hess_inv: array([[5.98752437]])
#       jac: array([-2.07126141e-06])
#   message: 'Optimization terminated successfully.'
#      nfev: 14
#       nit: 6
#      njev: 7
#    status: 0
#   success: True
#         x: array([4.13627618])

# %%
x0 = 30
result = minimize(fun, x0, method='BFGS')
print(result)
# Out:
#       fun: -11.898894665981285
#  hess_inv: array([[1.67932484]])
#       jac: array([2.38418579e-07])
#   message: 'Optimization terminated successfully.'
#      nfev: 14
#       nit: 6
#      njev: 7
#    status: 0
#   success: True
#         x: array([25.88019339])

# %% [markdown]
# Task 2

# %%
from scipy.optimize import differential_evolution

# %%
bounds = [(1, 30)]
result = differential_evolution(fun, bounds)
print(result)
# Out:
#      fun: array([-11.89889467])
#      jac: array([0.])
#  message: 'Optimization terminated successfully.'
#     nfev: 98
#      nit: 5
#  success: True
#        x: array([25.88019275])

# %% [markdown]
# Task 3

# %%
import matplotlib.pyplot as plt

# %%
def hfun(x):
    return int(fun(x))

# %%
for i in range(len(fx)):
    fx[i] = int(fx[i])



fig = plt.figure()
plt.plot(x, y)
plt.show()

# %%
x0 = 30
result = minimize(hfun, x0, method='BFGS')
print(result)
# Out:
#       fun: -5
#  hess_inv: array([[1]])
#       jac: array([0.])
#   message: 'Optimization terminated successfully.'
#      nfev: 2
#       nit: 0
#      njev: 1
#    status: 0
#   success: True
#         x: array([30.])

# %%
result = differential_evolution(hfun, bounds)
print(result)
# Out:
#      fun: -11.0
#  message: 'Optimization terminated successfully.'
#     nfev: 47
#      nit: 2
#  success: True
#        x: array([25.90870893])
